# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPabloSolano1/DR/blob/master/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(url)
print(iris.head(4))

iris.columns = ['sepal_length','sepal_width', 'petal_length', 'petal_width', 'class']
iris.head(2)

pd.isnull(iris).sum()

iris.iloc[10:30,2] = 1
iris.head(45)

del iris['class']
print (iris.head(2))

iris.iloc[0:3,0:4] = np.nan
print(iris.head(4))

iris = iris.dropna(how = 'any')
print(iris.head(3))

iris.reset_index(drop = True)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.0           1.4          0.2
# 1           4.7          3.2           1.3          0.2
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1           NaN          NaN           NaN          NaN
# 2           NaN          NaN           NaN          NaN
# 3           5.0          3.6           1.4          0.2
#    sepal_length  sepal_width  petal_length  petal_width
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4
# 5           4.6          3.4           1.4          0.3
#      sepal_length  sepal_width  petal_length  petal_width
# ...
