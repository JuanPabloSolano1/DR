# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPabloSolano1/DR/blob/master/Kaggle_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import sqlite3 as sq
from math import sqrt 
from random import shuffle

numbers = {'Banana':30,"Strawberry":21}
fruits = pd.DataFrame(index = [0],columns=['Banana','Strawberry'],data = [[30,21]])
fruits = pd.DataFrame(index = [0],columns = ['Banana','Strawberry'],data = numbers)
fruits

fruits = pd.DataFrame(index = ['Sales 2017','Sales 2018'],columns = ['Banana','Strawberry'],data = [[35,41],[21,34]])
fruits

ingredients = pd.Series(index = ['Flour','Milk','Eggs','Spam'], data = ['4 cups','1 cup','2 large','1 can'],name= 'Dinner')
ingredients

animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals

animals.to_csv('cows and goats.csv')

indices = list(range(0,10,2))
print(indices)

4 * (6 + 5)
4 * 6 + 5 
4 + 6 * 5 
type(3 + 1.5 + 4)
sqrt(144)
12**2

check = 'Hello'
check[1]
check[::-1]

check[-1]
check[4]
list_name = (0,0,0)
list(list_name)
list3 = [1,2,[3,4,'hello']]
list3[2][2] = 'good bye'

list3
list4 = [5,3,4,6,1]
list4.sort()
list4

d = {'simple_key':'hello'}
d['simple_key']

d = {'k1':{'k2':'hello'}}
d['k1']['k2']

d = {'k1':[{'nest_key':['this is deep',['hello']]}]}
d['k1'][0]['nest_key'][1]


d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}
d['k1'][2]['k2'][1]['tough'][2]

list5 = [1,2,2,33,4,4,11,22,3,3,2]
set(list5)

3.0 == 3
4**0.5 != 2

l_one = [1,2,[3,4]]
l_two = [1,2,{'k1':4}]

l_one[2][0] == l_two[2]['k1']


d = {
  'k1': 34,
  'k2': 25,
  'k3': 26
}
#Tuple umpacking (Important)
for key,value in d.items():
  print(value * 2)


x = 0
while x < 5:
  print (x)
  x += 3

for i in range(0,10,3):
  print (i)

word = 'abcde' 

for item in enumerate(word):
  print(item)

word = 'abcde'
numbers = [0,1,2,3,4,5]

for i in zip(word,numbers):
  print (i)

list(zip(word,numbers))

list_num = [1,2,3,4,5,6,7]
shuffle(list_num)

list_num

my_list = [x for x in 'word']
my_list

my_num = [x * 2 for x in range(0,10)]
my_num

my_num = [ x for x in range(0,10) if x % 2 == 0]
my_num

celcius = [0,10,32,45]
fahrenheit = [(9/5 * temp + 32) for temp in celcius]
fahrenheit

list_num = [x if x % 2 == 0 else 'ODD' for x in range(0,10)]
list_num

my_list = []

for i in [1,2,3]:
  for b in [2,3,4]:
    my_list.append(i * b)
my_list    

my_list = [ x * y for i in [1,2,3] for y in [2,3,4]]
my_list

my_list = [1,2,3,4]
help(my_list.insert)
# Out:
# [0, 2, 4, 6, 8]
# 68
# 50
# 52
# 0
# 3
# 0
# 3
# 6
# 9
# (0, 'a')
# (1, 'b')
# (2, 'c')
# (3, 'd')
# (4, 'e')
# ('a', 0)
# ('b', 1)
# ('c', 2)
# ('d', 3)
# ('e', 4)
# Help on built-in function insert:
#
# insert(...) method of builtins.list instance
#     L.insert(index, object) -- insert object before index
