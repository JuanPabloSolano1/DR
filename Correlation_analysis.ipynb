# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPabloSolano1/DR/blob/master/Correlation_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/JuanPabloSolano1/Doordash/master/Photos%20Analysis%20(Photos_Analysis)%20-%20Photos%20Analysis%20(Photos_Analysis).csv?token=Abk7lsJDa0_xiSB5tyu6JdryAubf8YxKks5cop8EwA%3D%3D'
check.head(1)

resolve = check.corr(method='pearson')
resolve

resolve2 = check['count_photos'].corr(check['booked_leads_February'])
print('The correlation for February is: {}'.format(resolve2))

resolve3 = check['count_photos'].corr(check['booked_leads_January'])
print('The correlation for January is: {}'.format(resolve3))

resolve4 = check['count_photos'].corr(check['booked_leads_March'])
print('The correlation for March is: {}'.format(resolve4))

check.plot.scatter('count_photos','booked_leads_March')

corr = check.corr(method='pearson')

corr.style.background_gradient(cmap='coolwarm')

sns.lmplot(x='count_photos', y='booked_leads_March', data=check,size = 7.15)

sns.lmplot

resolve = check.corr(method='pearson')
resolve
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# The correlation for February is: 0.07571670144160138
# The correlation for January is: 0.07032657405887467
# The correlation for March is: 0.07852280628583826
#                           customer_id  weekly_budget  count_photos  \
# customer_id                  1.000000      -0.000713     -0.026242
# weekly_budget               -0.000713       1.000000      0.015888
# count_photos                -0.026242       0.015888      1.000000
# charged_leads_January       -0.058115       0.062450      0.083544
# booked_leads_January        -0.038520       0.081698      0.070327
# conversion_rate_January     -0.016691       0.088145      0.048165
# ...
