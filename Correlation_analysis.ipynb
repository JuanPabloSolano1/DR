# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPabloSolano1/DR/blob/master/Correlation_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/JuanPabloSolano1/Doordash/master/Photos%20Analysis%20(Photos_Analysis)%20-%20Photos%20Analysis%20(Photos_Analysis).csv?token=Abk7lkflsMVMTgwSVbQAS2nJYmx31tDDks5cop1iwA%3D%3D'
check = pd.read_csv(url)
check.head(1)

resolve = check.corr(method='pearson')
resolve

resolve2 = check['count_photos'].corr(check['booked_leads_February'])
print(resolve2)

resolve3 = check['count_photos'].corr(check['booked_leads_January'])
print(resolve3)

resolve4 = check['count_photos'].corr(check['booked_leads_March'])
print(resolve4)

#sns.scatterplot(x='count_photos', y='booked_leads_March', data=check)

corr = check.corr(method='pearson')

corr.style.background_gradient(cmap='coolwarm')

sns.lmplot(x='count_photos', y='booked_leads_March', data=check,size = 10)

sns.lmplot
# Out:
# 0.07571670144160138
# 0.07032657405887467
# 0.07852280628583826
# <function seaborn.linearmodels.lmplot>
