# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPabloSolano1/DR/blob/master/Python_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
st = 'Print only the words that start with s in this sentence'
check = st.split()
print(check)

for i in check:
  if 's' in i[0]:
    print (i)

for i in range(0,11):
  if i % 2 == 0:
    print (i)

check = [x for x in range(0,50) if x % 3 == 0]   
print(check)

st = 'Print every word in this sentence that has an even number of letters'
check = st.split()
print(check)

for i in check:
  if len(i) % 2 ==0:
    print (i)


st = 'Create a list of the first letters of every word in this string'
check = [ x for x in st]  
print(check)

#Write a program that prints the integers from 1 to 100. But for multiples of three print "Fizz" instead of the number, and for the multiples of five print "Buzz". For numbers which are multiples of both three and five print "FizzBuzz".


for i in range(1,15):
  if i % 3 ==0 and i % 5 == 0:
    print('Fizbuzz')
  elif i % 3 == 0:
    print('Fizz')
  elif i % 5 == 0:
    print('Buzz')
  else:
    print (i)      

New_list = []
st = 'Create a list of the first letters of every word in this string'
check = st.split()
for i in check:
  New_list.append(i[0])
print(New_list)  
st = 'Create a list of the first letters of every word in this string' 
check = st.split()  

result = [word[0] for word in check]
print(result)

#if a word starts with a vowel + ay if not word -> ordway

def check_word(word):
  new_entry = word[0]
  if word[0] in 'aeiou':
    return word + 'ay'
  else:
    return word[1:len(word)-1] + new_entry  + 'ay'

check_word('word')  

#LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers if both numbers are even, but returns the greater if one or both numbers are odd
def check_number(x,y):
  if x % 2 ==0 and y % 2 ==0:
    return min(x,y)
  else:
    return max(x,y)

check_number(2,5)

#ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter

def check_word(string1):
  word_list = string1.split()
  if word_list[0][0] == word_list[1][0]:
    return True
  else:
    return False

check_word('Levelheaded Llama')     


def check_word(string1):
  word_list = string1.split()
  if word_list[0][0] == word_list[1][0]:
    print (word_list[1][0])
    print (word_list)

check_word('Levelheaded Llama') 

#Given two integers, return True if the sum of the integers is 20 or if one of the integers is 20. If not, return False¶

def check_integers(x,y):
  if x + y == 20 or x == 20 or y == 20:
    return True 
  else:
    return False

check_integers(20,10) 

#Write a function that capitalizes the first and fourth letters of a name

def capitalize(word):
  word_1 = word[0].upper()
  word_2 = word[3].upper()
  return word_1 + word[1:3] + word_2 + word[4:len(word)]

capitalize('macdonald')

# Given a sentence, return a sentence with the words reversed
def word_reversed(word):
  check = word.split()
  print(check)
  return check[len(check)-1] + " " + check[len(check)-2] + " " +check[0]
word_reversed('We are ready')


def interval(x):
  return (abs(100 - x) <= 10) or (abs(200 - x) <=10)

interval(104)    

#Given a list of ints, return True if the array contains a 3 next to a 3 somewhere.
def check_numbers(number):
  for i in range(0,len(number)-1):
    if (number[i]== 3) and (number[x+1]==3):
      return True
    return False  
check_numbers([2, 3, 3])

# Given a string, return a string where for every character in the original there are three characters
def check_word(string):
  check = list(string)
  for i in check:
    print ((i*3),end ="")

check_word('Hello')

#Given three integers between 1 and 11, if their sum is less than or equal to 21, return their sum. If their sum exceeds 21 and there's an eleven, reduce the total sum by 10. Finally, if the sum (even after adjustment) exceeds 21, return 'BUST'

def black_jack(a,b,c):
  if (a + b + c) <= 21:
    print (a+b+c)
  elif (a + b + c)> 21 and 11 in (a,b,c):
    print((a+b+c)-10)
  else:
    print('BLAST')  
black_jack(9,9,11) 

def blackjack(a,b,c):
    
    if sum((a,b,c)) <= 21:
        print (sum((a,b,c)))
    elif sum((a,b,c)) <=31 and 11 in (a,b,c):
        print (sum((a,b,c)) - 10)
    else:
        print ('BUST') 
blackjack(5,6,1) 

#Return the sum of the numbers in the array, except ignore sections of numbers starting with a 6 and extending to the next 9 (every 6 will be followed by at least one 9). Return 0 for no numbers.
def check_final(numbers):
  for i in range(0,len(numbers)-1):
    if 6 not in numbers and 9 not in numbers:
      print(sum(numbers))
      break
    elif numbers[i] == 6 and numbers[i + 1]== 9:
      print((sum(numbers)-6)-9)
    elif 6 not in numbers and 9 in numbers:
      print(9)
      break
    elif 6 in numbers and 9 not in numbers:
      check = numbers.remove(6)
      print(sum(numbers))
      break 
    elif numbers[i] == 6 and numbers[i + 1] != 9 and 9 in numbers:
      print(9)
      break
   
check_final([1, 3, 5,7,8,9])   

def summer_69(arr):
    total = 0
    add = True
    for num in arr:
        while add:
            if num != 6:
                total += num
                break
            else:
                add = False
        while not add:
            if num != 9:
                break
            else:
                add = True
                break
    return total
summer_69([3,4,5,6])  

def spy_game(num):
  code = [0,0,7,'x']
  for i in num:
    if i == code[0]:
      code.remove(i)
  print(len(code)==1)  
    

spy_game([1,0,3,8,9,0,7])

#Write a function that returns the number of prime numbers that exist up to and including a given number¶

def my_numbers(a,b,c=0,d=0,e=0):
  return(sum((a,b,c,d)) * 0.05)
my_numbers(3,4,5,9)  

#Really important 
def my_numbers1(*args):
  return(sum((args)))

my_numbers1(30,40,50)

def my_test(*args):
  for i in args:
    print(str(i) + ',' , end="")
my_test(3,4,5,6)    

#Important
def check_numbers(**kwargs):
  for i in kwargs:
    if "fruits" in kwargs:
      print('my favorite fruit is {}'.format(kwargs['fruits']))
check_numbers(fruits = 'Apple', veggie = 'Lettuce') 

def check_both(*args,**kwargs):
  print('I would like {} {}'.format(args[0],kwargs['food']))

check_both(10,20,20,food = 'eggs')
# Out:
# ['Print', 'only', 'the', 'words', 'that', 'start', 'with', 's', 'in', 'this', 'sentence']
# start
# s
# sentence
# 0
# 2
# 4
# 6
# 8
# 10
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]
# ['Print', 'every', 'word', 'in', 'this', 'sentence', 'that', 'has', 'an', 'even', 'number', 'of', 'letters']
# word
# in
# this
# sentence
# that
# an
# even
# number
# of
# ['C', 'r', 'e', 'a', 't', 'e', ' ', 'a', ' ', 'l', 'i', 's', 't', ' ', 'o', 'f', ' ', 't', 'h', 'e', ' ', 'f', 'i', 'r', 's', 't', ' ', 'l', 'e', 't', 't', 'e', 'r', 's', ' ', 'o', 'f', ' ', 'e', 'v', 'e', 'r', 'y', ' ', 'w', 'o', 'r', 'd', ' ', 'i', 'n', ' ', 't', 'h', 'i', 's', ' ', 's', 't', 'r', 'i', 'n', 'g']
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# ['C', 'a', 'l', 'o', 't', 'f', 'l', 'o', 'e', 'w', 'i', 't', 's']
# ['C', 'a', 'l', 'o', 't', 'f', 'l', 'o', 'e', 'w', 'i', 't', 's']
# L
# ['Levelheaded', 'Llama']
# ['We', 'are', 'ready']
# HHHeeellllllooo19
# 12
# 9
# ...
